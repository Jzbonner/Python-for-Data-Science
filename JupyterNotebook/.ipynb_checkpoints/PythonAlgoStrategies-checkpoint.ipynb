# %%
import pandas as pd 

data = pd.read_pickle("PythonScripts/b_h.pickle")
data.fillna('')

data[['algo_volatility', 'alpha', 'beta', 'starting_cash', 'ending_cash']]
# Out:
#                            algo_volatility     alpha      beta  starting_cash  \
# 2018-03-01 21:00:00+00:00              NaN       NaN       NaN      1000000.0
# 2018-03-02 21:00:00+00:00         0.000022 -0.000372 -0.000102      1000000.0
# 2018-03-05 21:00:00+00:00         0.001109  0.009275  0.003490       973072.0
# 2018-03-06 21:00:00+00:00         0.001136  0.003539  0.003152       973072.0
# 2018-03-07 21:00:00+00:00         0.001338 -0.002743  0.003557       973072.0
# 2018-03-08 21:00:00+00:00         0.002045  0.006612  0.005620       973072.0
# 2018-03-09 21:00:00+00:00         0.003432  0.012250  0.014432       973072.0
# 2018-03-12 20:00:00+00:00         0.003221  0.018428  0.013257       973072.0
# 2018-03-13 20:00:00+00:00         0.004100  0.004741  0.018067       973072.0
# 2018-03-14 20:00:00+00:00         0.004089  0.000937  0.019230       973072.0
# 2018-03-15 20:00:00+00:00         0.003881  0.002629  0.019020       973072.0
# ...
